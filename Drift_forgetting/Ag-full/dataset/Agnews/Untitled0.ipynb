# %%
# %cd /content/drive/MyDrive/Agnews_forget_drift/preprocessing/Agnews/
# Out:
# /content/drive/MyDrive/Agnews_forget_drift/preprocessing/Agnews

# %%
# !python holdout_process.py 100 500
# Out:
# Class 0: 60 minibatches
# Class 1: 60 minibatches
# Class 2: 60 minibatches
# Class 3: 60 minibatches
# Write setting file...
# ...
# Split data in all class into two sets...
# Processing class-1.txt
# length of data is  29500
# length of hold-out is  500
#
# Processing class-2.txt
# length of data is  29500
# length of hold-out is  500
#
# Processing class-3.txt
# length of data is  29500
# length of hold-out is  500
#
# Processing class-4.txt
# length of data is  29500
# length of hold-out is  500
#
# ...
# Concatenate all training file...
#
#
# Total time process: 0.8603484630584717
