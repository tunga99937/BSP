# %%
# %cd /content/drive/MyDrive/Agnews_forget_drift/preprocessing/Agnews-title/
# Out:
# /content/drive/MyDrive/Agnews_forget_drift/preprocessing/Agnews-title

# %%
# !python holdout_process.py 100 500
# Out:
# Class 0: 59 minibatches
# Class 1: 58 minibatches
# Class 2: 59 minibatches
# Class 3: 59 minibatches
# Write setting file...
# ...
# Split data in all class into two sets...
# Processing class-1.txt
# length of data is  29000
# length of hold-out is  500
#
# Processing class-2.txt
# length of data is  28500
# length of hold-out is  500
#
# Processing class-3.txt
# length of data is  29000
# length of hold-out is  500
#
# Processing class-4.txt
# length of data is  29000
# length of hold-out is  500
#
# ...
# Concatenate all training file...
#
#
# Total time process: 0.839996337890625
