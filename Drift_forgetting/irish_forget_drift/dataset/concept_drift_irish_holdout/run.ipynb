# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/irish_forget_drift/dataset/concept_drift_irish_holdout/
# Out:
# /content/drive/MyDrive/irish_forget_drift/dataset/concept_drift_irish_holdout

# %% [markdown]
# ### Modify the order in concatenate function in holdout_process.py after running

# %%
# !python holdout_process.py 100 2000
# Out:
# Class 0: 35 minibatches
# Class 1: 91 minibatches
# Class 2: 33 minibatches
# Class 3: 357 minibatches
# Class 4: 56 minibatches
# Class 5: 112 minibatches
# Write setting file...
# ...
# Split data in all class into two sets...
# Processing class-0.txt
# length of data is  68000
# length of hold-out is  2000
#
# Processing class-1.txt
# length of data is  180000
# length of hold-out is  2000
#
# Processing class-2.txt
# length of data is  64000
# length of hold-out is  2000
#
# Processing class-3.txt
# length of data is  712000
# length of hold-out is  2000
#
# Processing class-4.txt
# length of data is  110000
# length of hold-out is  2000
#
# Processing class-5.txt
# length of data is  222000
# length of hold-out is  2000
#
# ...
# Concatenate all training file...
#
#
# Total time process: 6.707407474517822
