# %%
# %cd /content/drive/MyDrive/uci_forget_drift/uci-data/
# Out:
# /content/drive/MyDrive/uci_forget_drift/uci-data

# %%
# !python holdout_process.py 100 2000
# Out:
# Class 0: 57 minibatches
# Class 1: 53 minibatches
# Class 2: 75 minibatches
# Class 3: 22 minibatches
# Write setting file...
# ...
# Split data in all class into two sets...
# Processing class-1.txt
# length of data is  112000
# length of hold-out is  2000
#
# Processing class-2.txt
# length of data is  104000
# length of hold-out is  2000
#
# Processing class-3.txt
# length of data is  148000
# length of hold-out is  2000
#
# Processing class-4.txt
# length of data is  42000
# length of hold-out is  2000
#
# ...
# Concatenate all training file...
#
#
# Total time process: 2.761322498321533
